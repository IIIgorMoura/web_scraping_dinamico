# %% [markdown]
# # Tratamento
#
# Remover OUTLIERS:
#     Na categoria 'Placa de Vídeo', há alguns produtos que são complementares e não GPUs em si;
#     Remover valores muito baixos (abaixo de 1000?);

# %%
# %pip install pandas matplotlib openpyxl selenium

# %%
import pandas as pd
df = pd.read_excel('webscraping.xlsx')
df
# Out:
#                                                   nome        preco  \
# 0    Placa de Vídeo RX 7600 GAMING OC 8G AMD Radeon...  R$ 1.799,99
# 1    Placa de Vídeo RX 6600 CLD 8G ASRock AMD Radeo...  R$ 1.659,99
# 2    Placa de Vídeo RX 6750XT Gaming XFX Graphics C...  R$ 2.799,99
# 3    Placa de Video RTX 4060 Infinity 2 Palit NVIDI...  R$ 2.299,99
# 4    Placa de Vídeo RX 6650XT XFX Speedster SWFT210...  R$ 1.879,99
# ..                                                 ...          ...
# 457  Placa de Video 1Gb GT710 Ddr3 64bit Vga/Dvi/Hd...    R$ 323,83
# 458  Placa de Vídeo AFOX GeForce GTX750TI, 2GB, GDD...  R$ 1.004,40
# 459  Placa de Vídeo Gainward NVIDIA GeForce GTX 166...  R$ 5.592,00
# 460  Adaptador Para Duas Fontes E Mineração Psuad 2...     R$ 21,90
# 461  Bloco VGA Barrow Para Rtx 3080 (ti) E Rtx 3090...    R$ 599,00
#
#      frete_gratis
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ..            ...
# 457         False
# 458         False
# 459          True
# 460         False
# 461         False
#
# [462 rows x 3 columns]
