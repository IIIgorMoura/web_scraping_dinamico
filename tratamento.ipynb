# %% [markdown]
# # Tratamento
#
# Remover OUTLIERS:
#
#     Na categoria 'Placa de Vídeo', há alguns produtos que são complementares e não GPUs em si;
#     Remover valores muito baixos (abaixo de 1000?);
#
# \
# Extrair Performance Status das GPUs

# %%
# %pip install pandas matplotlib openpyxl selenium numpy

# %%
import pandas as pd
df = pd.read_excel('webscraping.xlsx')
df
# Out:
#                                                   nome        preco  \
# 0    Placa de Vídeo RX 7600 GAMING OC 8G AMD Radeon...  R$ 1.799,99
# 1    Placa de Vídeo RX 6600 CLD 8G ASRock AMD Radeo...  R$ 1.659,99
# 2    Placa de Vídeo RX 6750XT Gaming XFX Graphics C...  R$ 2.799,99
# 3    Placa de Video RTX 4060 Infinity 2 Palit NVIDI...  R$ 2.299,99
# 4    Placa de Vídeo RX 6650XT XFX Speedster SWFT210...  R$ 1.879,99
# ..                                                 ...          ...
# 457  Placa de Video 1Gb GT710 Ddr3 64bit Vga/Dvi/Hd...    R$ 323,83
# 458  Placa de Vídeo AFOX GeForce GTX750TI, 2GB, GDD...  R$ 1.004,40
# 459  Placa de Vídeo Gainward NVIDIA GeForce GTX 166...  R$ 5.592,00
# 460  Adaptador Para Duas Fontes E Mineração Psuad 2...     R$ 21,90
# 461  Bloco VGA Barrow Para Rtx 3080 (ti) E Rtx 3090...    R$ 599,00
#
#      frete_gratis
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# ..            ...
# 457         False
# 458         False
# 459          True
# 460         False
# 461         False
#
# [462 rows x 3 columns]

# %% [markdown]
# ### OUTLIERS
#
# Neste caso, OUTLIERS acima fazem sentido \
# Porém, há itens inválidos e muito abaixo do preço
#
# Usar interquantil neste caso não é o método mais eficiente

# %%
import numpy as np

df['preco'] = df['preco'].str.replace('R$ ', '').str.replace('.', '').str.replace(',', '.')
df['preco'] = df['preco'].astype(float)

df.info()

q1 = df['preco'].quantile(0.25)
q3 = df['preco'].quantile(0.75)

iqr = q3 - q1

limite_minimo = q1 - 1.5 * iqr
limite_maximo = q3 + 1.5 * iqr

acima_outliers = df[df['preco'] > limite_maximo]
abaixo_outliers = df[df['preco'] < limite_minimo]

display(acima_outliers, abaixo_outliers)

print(limite_maximo, limite_minimo)
print(df['preco'].mean())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome          462 non-null    object
#  1   preco         462 non-null    float64
#  2   frete_gratis  462 non-null    bool
# dtypes: bool(1), float64(1), object(1)
# memory usage: 7.8+ KB
#                                                   nome     preco  frete_gratis
# 44   Placa de Vídeo ASUS RTX5090 ROG Astral Gaming ...  29999.99          True
# 76   Placa de Vídeo Gigabyte RTX 5080 AORUS MASTER,...  13999.99          True
# 84   Placa de Vídeo ASUS TUF RTX5090 O32G GAMING, N...  23999.99          True
# 107  Placa de Vídeo Palit RTX 5090 GameRock OC NVID...  22999.99          True
# 118  Placa de Vídeo Gigabyte RTX 5090 WINDFORCE OC ...  23999.99          True
# 128  Placa de Vídeo RTX 5090 GAMING OC 32G Gigabyte...  25999.99          True
# 142  Placa de Vídeo RTX 5080 AORUS XTREME WATERFORC...  13999.99          True
# 186  Placa de Vídeo RTX 5080 AORUS MASTER ICE 16G G...  13999.99          True
# 222  Placa de Vídeo RTX 5080 WINDFORCE OC SFF 16G G...  13999.99          True
# 223  Placa de Vídeo RTX 5000 Ada PNY NVIDIA Quadro ...  28999.99          True
# 241  Placa de Vídeo Palit RTX 5090 GameRock NVIDIA ...  19999.99          True
# 250  Placa de Vídeo Quadro A800 PNY Nvidia, 40GB HB...  69999.99          True
# 251  Placa De Video Gigabyte Geforce RTX 5080 Aorus...  14035.50         False
# 284  Placa De Video Pny Nvidia Quadro RTX 5000 Ada ...  41795.73         False
# 326  Placa De Vídeo Msi RTX 5080 16gb Ventus 3x Oc,...  15122.60          True
# 391  Placa De Vídeo Msi RTX 5080 16g Gaming Trio Oc...  14999.90         False
# 409                            MBA 13 SLV 10C GPU 24GB  13499.10         False
# 410                            MBA 15 SLV 10C GPU 24GB  14579.10         False
# 438  Placa De Vídeo Msi RTX 5090 32gb Gaming Trio O...  33470.80          True
# 442  Placa De Vídeo Quadro RTX 4500 Ada Generation ...  26687.28         False
# 445  Placa De Vídeo Zotac RTX 5090 32gb Solid Oc, G...  26868.59         False
# Empty DataFrame
# Columns: [nome, preco, frete_gratis]
# Index: []
# 13322.868749999998 -7130.9612499999985
# 4014.4219480519478

# %% [markdown]
# ### Remoção de itens inválidos encontrados

# %%
# display(len(df[df['preco'] < 200]))
# display(df[df['preco'] < 200].sort_values(by='preco'))

display(df[df['nome'].str.contains('suporte|cabo|adaptador|bloco|captura|controladora', case=False)])
df = df[~df['nome'].str.contains('suporte|cabo|adaptador|bloco|captura|controladora', case=False)]

df.info()
# Out:
#                                                   nome    preco  frete_gratis
# 41   Suporte Para Placa De Vídeo Ntc, R10, Preto - ...    17.77         False
# 64   Cabo Extensor PCI Express Rise Mode Riser - RM...   159.99          True
# 98   Suporte para Placa de Vídeo Cooler Master Atla...   159.99          True
# 111  Suporte Para Placa De Vídeo Ntc R10, Branco - ...    17.77         False
# 120  Suporte P/ Placa De Vídeo Ajustável Preto Com ...    64.99         False
# 172  Suporte Para Placa De Vídeo Ntc R15, Branco - ...    24.90         False
# 192  Suporte Placa De Vídeo Vertical, Rosqueável 50...    42.61         False
# 208  Suporte Argb Para Placa De Video Cooler Master...   237.85         False
# 215  Suporte Para Placa De Vídeo (GPU) GH3 PRO, Coo...   195.16          True
# 273  Suporte Placa De Vídeo Infinity, Led, Argb, In...   159.32         False
# 278  Suporte Para Placa De Vídeo Vertical Redragon ...    99.00         False
# 295  Suporte Placa De Vídeo Coolmoon, Vertical, Bra...   112.53          True
# 298  Placa De Video Nvidia Gt 1030 4gb GDDR4 64bit ...   794.43         False
# 303  Suporte Para Placa De Vídeo Vertical Redragon ...   102.00          True
# 321  Cabo Riser Pci-e 3.0 X16 Thermaltake Premium -...   575.15         False
# 330  Suporte P/ Placa De Video, Em Gabinete, Deepco...   229.90         False
# 345  Suporte Vertical Gpu Placa De Video Bracket PC...   539.00         False
# 352  Bloco Vga Barrow Para Rtx 3080, 3080 Ti E 3090...   699.00         False
# 373  Bloco Vga Barrow Para Rtx 3060ti E 3070 Asus S...   599.00         False
# 381  Suporte Para Placa De Video Com Iluminacao ARG...   511.42         False
# 402  Placa Controladora Cabeça Impressão Lexmark X9...  2272.68         False
# 403  Placa De Captura ELGA to Game Capture Hd60 S U...  2900.00         False
# 460  Adaptador Para Duas Fontes E Mineração Psuad 2...    21.90         False
# 461  Bloco VGA Barrow Para Rtx 3080 (ti) E Rtx 3090...   599.00         False
# <class 'pandas.core.frame.DataFrame'>
# Index: 438 entries, 0 to 459
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nome          438 non-null    object
#  1   preco         438 non-null    float64
#  2   frete_gratis  438 non-null    bool
# dtypes: bool(1), float64(1), object(1)
# memory usage: 10.7+ KB

# %% [markdown]
# ### Separação por marca e modelo

# %%
df['nome'] = df['nome'].str.replace('placa de vídeo ', '', case=False).str.replace('placa de video ', '', case=False)
df
# Out:
# C:\Users\Igor Moura\AppData\Local\Temp\ipykernel_12376\655573015.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nome'] = df['nome'].str.replace('placa de vídeo ', '', case=False).str.replace('placa de video ', '', case=False)
#                                                   nome    preco  frete_gratis
# 0    RX 7600 GAMING OC 8G AMD Radeon Gigabyte, 8GB,...  1799.99          True
# 1    RX 6600 CLD 8G ASRock AMD Radeon, 8GB, GDDR6 -...  1659.99          True
# 2    RX 6750XT Gaming XFX Graphics Card AMD Radeon,...  2799.99          True
# 3    RTX 4060 Infinity 2 Palit NVIDIA GeForce, 8GB,...  2299.99          True
# 4    RX 6650XT XFX Speedster SWFT210 AMD Radeon, 8G...  1879.99          True
# ..                                                 ...      ...           ...
# 455  XFX AMD RADEON RX 7600 Gaming Graphics Card, 8...  2299.99         False
# 456                          Nvidia Geforce Gt210/1g 1   145.35          True
# 457  1Gb GT710 Ddr3 64bit Vga/Dvi/Hdmi Low Profile ...   323.83         False
# 458  AFOX GeForce GTX750TI, 2GB, GDDR5, 128 Bits, H...  1004.40         False
# 459  Gainward NVIDIA GeForce GTX 1660 Super, 6GB GD...  5592.00          True
#
# [438 rows x 3 columns]

# %%
marcas = [
    'ASUS', 'MSI', 'Gigabyte', 'EVGA', 'Zotac', 'Palit', 'Galax', 'Sapphire', 'XFX', 'PowerColor', 'PNY', 'Leadtek', 'Inno3D', 'KFA2', 'Biostar', 'HIS', 'Club3D', 'VTX3D', 'ASRock', 'Shenzhen Zotac', 'Galaxy', 'Maxsun', 'Albatron', 'PCYes'
]

def extrair_marca(texto):
    texto = texto.lower()
    for marca in marcas:
        if marca.lower() in texto:
            return marca
    return 'Desconhecida'

df['marca'] = df['nome'].apply(extrair_marca)

df
# Out:
# C:\Users\Igor Moura\AppData\Local\Temp\ipykernel_12376\3076609290.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marca'] = df['nome'].apply(extrair_marca)
#                                                   nome    preco  frete_gratis  \
# 0    RX 7600 GAMING OC 8G AMD Radeon Gigabyte, 8GB,...  1799.99          True
# 1    RX 6600 CLD 8G ASRock AMD Radeon, 8GB, GDDR6 -...  1659.99          True
# 2    RX 6750XT Gaming XFX Graphics Card AMD Radeon,...  2799.99          True
# 3    RTX 4060 Infinity 2 Palit NVIDIA GeForce, 8GB,...  2299.99          True
# 4    RX 6650XT XFX Speedster SWFT210 AMD Radeon, 8G...  1879.99          True
# ..                                                 ...      ...           ...
# 455  XFX AMD RADEON RX 7600 Gaming Graphics Card, 8...  2299.99         False
# 456                          Nvidia Geforce Gt210/1g 1   145.35          True
# 457  1Gb GT710 Ddr3 64bit Vga/Dvi/Hdmi Low Profile ...   323.83         False
# 458  AFOX GeForce GTX750TI, 2GB, GDDR5, 128 Bits, H...  1004.40         False
# 459  Gainward NVIDIA GeForce GTX 1660 Super, 6GB GD...  5592.00          True
#
#             marca
# 0        Gigabyte
# 1          ASRock
# 2             XFX
# 3           Palit
# 4             XFX
# ..            ...
# 455           XFX
# 456  Desconhecida
# 457  Desconhecida
# 458  Desconhecida
# 459  Desconhecida
#
# [438 rows x 4 columns]

# %%
fabricantes_chip = [
    'NVIDIA', 'AMD', 'Intel'
]

def extrair_chip(texto):
    texto = texto.lower()
    for chip in fabricantes_chip:
        if chip.lower() in texto:
            return chip
        elif 'RX'.lower() in texto:
            return 'AMD'
        elif 'GeForce'.lower() in texto or 'RTX' in texto or 'GTX' in texto or 'GT' in texto:
            return 'NVIDIA'
    return 'Desconhecido'

df['chip'] = df['nome'].apply(extrair_chip)
# Out:
# C:\Users\Igor Moura\AppData\Local\Temp\ipykernel_12376\2262231834.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['chip'] = df['nome'].apply(extrair_chip)

# %%
# biblioteca padrão python
import re

df['memoria_gb'] = df['nome'].str.extract(r'(\d+)\s*(MB|mb|GB|gb)', flags=re.IGNORECASE)[0]
# df['memoria_gb'] = df['memoria_gb'].astype(int)

# display(df[df['memoria_gb'] > 16])

display(df[df['memoria_gb'].isna()])
# Out:
# C:\Users\Igor Moura\AppData\Local\Temp\ipykernel_12376\2795569158.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['memoria_gb'] = df['nome'].str.extract(r'(\d+)\s*(MB|mb|GB|gb)', flags=re.IGNORECASE)[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[449], line 7
#       4 df['memoria_gb'] = df['nome'].str.extract(r'(\d+)\s*(MB|mb|GB|gb)', flags=re.IGNORECASE)[0]
#       5 # df['memoria_gb'] = df['memoria_gb'].astype(int)
# ----> 7 display(df[df['memoria_gb'] > 16])
#       9 display(df[df['memoria_gb'].isna()])
#
# File c:\Anaconda\envs\testsIniciaisENV\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Anaconda\envs\testsIniciaisENV\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Anaconda\envs\testsIniciaisENV\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Anaconda\envs\testsIniciaisENV\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File c:\Anaconda\envs\testsIniciaisENV\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# df.to_excel('webscraping_limpo.xlsx', index=False)
